# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/Boroughs_of_New_York_City"
page = requests.get(url)
pagetext = page.text

# %%
scraper = BeautifulSoup(pagetext, 'html.parser')
table = scraper.find('table')

list_of_rows = []
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll(["th","td"]):
        text = cell.text
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

for item in list_of_rows:
    print(' '.join(item))
# Out:
# New York City's five boroughsvte
#
# Jurisdiction
#  Population
#  Land area
#  Density of population
#  GDP †
#
# Borough County Census (2020) square miles squarekm people/sq. mile people/sq. km billions(2012 US$) 2
#
# The Bronx
#
#   Bronx
#  1,472,654
#  42.2
#  109.3
#  34,920
#  13,482
#  $38.726
#
# Brooklyn
#
#   Kings
#  2,736,074
#  69.4
#  179.7
#  39,438
#  15,227
#  $92.300
#
# Manhattan
#
#   New York
#  1,694,251
#  22.7
#  58.8
#  74,781
#  28,872
#  $651.619
#
# Queens
#
#    Queens
#  2,405,464
#  108.7
#  281.5
#  22,125
#  8,542
#  $88.578
#
# Staten Island
#
#    Richmond
#  495,747
#  57.5
#  148.9
#  8,618
#  3,327
#  $14.806
#
# City of New York 8,804,190 302.6 783.8 29,095 11,234 $885.958
#
# State of New York 20,215,751 47,126.4 122,056.8 429 166 $1,514.779
#
# † GDP = Gross Domestic Product    Sources:[3][4][5][6] and see individual borough articles.

# %%
df = pd.DataFrame(list_of_rows)

# %%
df.head(15)
# Out:
#                                                     0                1
# 0                  New York City's five boroughsvte\n             None  \
# 1                                      Jurisdiction\n     Population\n
# 2                                             Borough           County
# 3                                         The Bronx\n      \n  Bronx\n
# 4                                          Brooklyn\n      \n  Kings\n
# 5                                         Manhattan\n   \n  New York\n
# 6                                            Queens\n    \n   Queens\n
# 7                                     Staten Island\n  \n   Richmond\n
# 8                                    City of New York        8,804,190
# 9                                   State of New York       20,215,751
# 10  † GDP = Gross Domestic Product    Sources:[3][...             None
#
#                 2                        3         4                5
# 0            None                     None      None             None  \
# 1     Land area\n  Density of population\n   GDP †\n             None
# 2   Census (2020)             square miles  squarekm  people/sq. mile
# 3     1,472,654\n                   42.2\n   109.3\n         34,920\n
# 4     2,736,074\n                   69.4\n   179.7\n         39,438\n
# 5     1,694,251\n                   22.7\n    58.8\n         74,781\n
# 6     2,405,464\n                  108.7\n   281.5\n         22,125\n
# 7       495,747\n                   57.5\n   148.9\n          8,618\n
# 8           302.6                    783.8    29,095           11,234
# 9        47,126.4                122,056.8       429              166
# 10           None                     None      None             None
#
#                 6                       7
# 0            None                    None
# 1            None                    None
# 2   people/sq. km  billions(2012 US$) 2\n
# 3        13,482\n               $38.726\n
# 4        15,227\n               $92.300\n
# 5        28,872\n              $651.619\n
# 6         8,542\n               $88.578\n
# 7         3,327\n               $14.806\n
# 8      $885.958\n                    None
# 9    $1,514.779\n                    None
# 10           None                    None
